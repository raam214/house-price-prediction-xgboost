# %% [markdown]
# # House Price Prediction using XGBoost
#
# A machine learning project demonstrating an end-to-end regression workflow
# using modular Python code and XGBoost.

# %% [markdown]
# ## Problem Statement
#
# The objective of this project is to build a machine learning model that can
# predict house prices based on various features describing residential properties.
#
# The project follows a clean, production-style machine learning workflow where:
# - Core logic is implemented as reusable Python modules
# - The notebook is used for explanation and demonstration
# - Model training and evaluation are performed using XGBoost

# %% [markdown]
# ## Dataset
#
# - **Dataset Name:** Ames Housing Dataset
# - **Source:** Kaggle – House Prices: Advanced Regression Techniques
# - **Target Variable:** SalePrice
#
# > Note:
# > The dataset is not included in this repository.
# > Data loading and preprocessing are handled inside Python modules located in the `src/` directory.

# %%
from src.feature_engineering import scale_features

# Assuming cleaned data is provided by the preprocessing module
# Feature scaling improves model performance for XGBoost

# %% [markdown]
# ## Feature Engineering
#
# Numerical features are scaled using `StandardScaler` to ensure that all features
# contribute equally during model training.
#
# Feature engineering logic is implemented in a reusable Python module:
# `src/feature_engineering.py`

# %%
from src.train_model import train_model

# The XGBoost regression model is trained using scaled features

# %% [markdown]
# ## Model Training
#
# An XGBoost Regressor is trained on the prepared dataset.
# The training logic is separated into a dedicated module to maintain clean code
# and improve reusability.

# %%
from src.evaluate_model import evaluate_model

# Model performance is evaluated using RMSE and R² score

# %% [markdown]
# ## Model Evaluation
#
# The trained model is evaluated using standard regression metrics:
# - Root Mean Squared Error (RMSE)
# - R² Score
#
# Evaluation logic is implemented in `src/evaluate_model.py`.

# %% [markdown]
# ## Conclusion
#
# This project demonstrates a clean and modular approach to building
# machine learning models using Python and XGBoost.
#
# By separating data processing, feature engineering, training, and evaluation
# into independent modules, the project follows best practices suitable for
# real-world production systems.
